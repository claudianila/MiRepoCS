# %% [markdown]
# # B3S1 Gráficos para el Análisis Exploratorio Bivariado

# %%
#Importamos librerías
import pandas as pd
import numpy as np
import seaborn as sns

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
#Basado en la sección de visualización del libro Python Data Science Handbook

# %% [markdown]
# # Ejemplo 1
# Graficaremos, como ejemplo, la función seno y coseno

# %%
#El manual de usuario de Matplotlib se puede consultar en: https://matplotlib.org/stable/tutorials/introductory/usage.html#sphx-glr-tutorials-introductory-usage-py

# %%
#Creación de nuevas figuras en pyplot
fig = plt.figure()  # crea una figura vacía sin Axes
fig, ax = plt.subplots()  # crea una figura con un solo Axes
fig, axs = plt.subplots(2, 2)  # crea una figura con un arreglo de 2x2 de Axes
#Axes es donde se grafica propiamente y contien diversos elementos

# %%
fig = plt.gcf()  #es análoga a hacer un plt.figure cuando no hay más figuras
x = np.linspace(0, 10, 100)
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

# %% [markdown]
# Se puede guardar la figura como un archivo png con la instrucción savefig.

# %%
fig.savefig('my_figure.png')

# %%
fig.canvas.get_supported_filetypes()
# Out:
# {'eps': 'Encapsulated Postscript',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format'}

# %%
#Gráficos tipo herencia de Matlab para gráficos por subplot
plt.figure() # create a plot figure
# create the first of two panels and set current axis
plt.subplot(2, 1, 1) # (rows, columns, panel number)
plt.plot(x, np.sin(x))
# create the second panel and set current axis
plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x));

# %%
#Alternativa cuando se crean los dos marcos de una vez
# First create a grid of plots
# ax will be an array of two Axes objects
fig, ax = plt.subplots(2)
# Call plot() method on the appropriate object
ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.cos(x));

# %%
#Uso de ax
fig = plt.figure()
ax = plt.axes()

# %%
#Gráfico creado bajo el enfoque de programación orientada a objetos
fig = plt.figure()
ax = plt.axes()
x = np.linspace(0, 10, 1000)
ax.plot(x, np.sin(x));

# %%
#Modo bajo el enfoque de programación estructurada
plt.plot(x, np.sin(x))

# %% [markdown]
# Y podemos llamar varias veces la función plot para graficar varias líneas

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

# %% [markdown]
# ### Ajuste de la gráfica: Color y estilos

# %%
#plt.plot(x, np.sin(x - 0), color='blue') # especifica el color por nombre
plt.plot(x, np.sin(x - 1), color='g') # código corto de color (rgbcmyk)
plt.plot(x, np.sin(x - 2), color='0.75') # Escala de grises entre 0 y 1
plt.plot(x, np.sin(x - 3), color='#FFDD44') # Código Hex (RRGGBB de 00 a FF)
plt.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3)) # tupla RGB, valores 0 a 1
plt.plot(x, np.sin(x - 5), color='chartreuse'); # todos los nombres HTML de color supportados

# %%
plt.plot(x, x + 0, linestyle='solid')
plt.plot(x, x + 1, linestyle='dashed')
plt.plot(x, x + 2, linestyle='dashdot')
plt.plot(x, x + 3, linestyle='dotted');
# For short, you can use the following codes:
plt.plot(x, x + 4, linestyle='-') # solid
plt.plot(x, x + 5, linestyle='--') # dashed
plt.plot(x, x + 6, linestyle='-.') # dashdot
plt.plot(x, x + 7, linestyle=':'); # dotted

# %% [markdown]
# También podemos combinar estilos de línea y color

# %%
plt.plot(x, x + 0, '-g') # solid green
plt.plot(x, x + 1, '--c') # dashed cyan
plt.plot(x, x + 2, '-.k') # dashdot black
plt.plot(x, x + 3, ':r'); # dotted red

# %% [markdown]
# ### Ajuste de la gráfica: Límites de los Ejes

# %%
plt.plot(x, np.sin(x))
plt.xlim(-1, 11)
plt.ylim(-1.5, 1.5);

# %% [markdown]
# Forma alternativa, utilizando un vector que tiene
# [xmin , xmax , ymin , ymax]

# %%
plt.plot(x, np.sin(x))
plt.axis([-1, 11, -1.5, 1.5]);

# %% [markdown]
# Ajuste automático

# %%
plt.plot(x, np.sin(x))
plt.axis('tight');

# %% [markdown]
# En la siguiente gráfica, una unidad en el eje x es equivalente a una unidad en el eje y

# %%
plt.plot(x, np.sin(x))
plt.axis('equal');

# %% [markdown]
# ### Etiquetas de la gráfica

# %%
plt.plot(x, np.sin(x))
plt.title("Curva Seno")
plt.xlabel("x")
plt.ylabel("sin(x)");

# %%
plt.plot(x, np.sin(x), '-g', label='sin(x)')
plt.plot(x, np.cos(x), ':b', label='cos(x)')
plt.axis('equal')
plt.legend();

# %% [markdown]
# En el enfoque orientado a objetos, (con ax), podemos especificar diversas características con ax.set

# %%
ax = plt.axes()
ax.plot(x, np.sin(x))
ax.set(xlim=(0, 10), ylim=(-2, 2),
xlabel='x', ylabel='sin(x)',
title='Un gráfico simple');

# %% [markdown]
# # Gráficos de dispersión

# %%
x = np.linspace(0, 10, 30)
y = np.sin(x)
plt.plot(x, y, 'o', color='black');

# %%
rng.rand(5)
# Out:
# array([0.44712538, 0.84640867, 0.69947928, 0.29743695, 0.81379782])

# %%
rng = np.random.RandomState(0)
for marker in ['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd']:
    plt.plot(rng.rand(5), rng.rand(5), marker,
             label="marker='{0}'".format(marker))
    plt.legend(numpoints=1)
    plt.xlim(0, 1.8);

# %%
plt.plot(x, y, '-ok'); # line (-), circle marker (o), black (k)

# %%
plt.plot(x, y, '-p', color='gray',
markersize=15, linewidth=4,
markerfacecolor='white',
markeredgecolor='gray',
markeredgewidth=2)
plt.ylim(-1.2, 1.2);

# %% [markdown]
# # Scatter plot
# La principal diferencia entre plt.scatter y plt.plot es que se puede usar para crear gráficos de dispersión donde
# las propiedades de cada punto individual (tamaño, color de cara, color de borde, etc) pueden controlar
# o mapear de forma individual a los datos.

# %%
plt.scatter(x, y, marker='o');

# %%
rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)
plt.scatter(x, y, c=colors, s=sizes, alpha=0.3,  #alpha es el nivel de transparencia y permite visualizar resultados que se traslapan
cmap='viridis')
plt.colorbar(); # show color scale
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8ecf1c6d8a14> in <module>
# ----> 1 rng = np.random.RandomState(0)
#       2 x = rng.randn(100)
#       3 y = rng.randn(100)
#       4 colors = rng.rand(100)
#       5 sizes = 1000 * rng.rand(100)
#
# NameError: name 'np' is not defined

# %%
# Ejemplo con los datos de Iris
from sklearn.datasets import load_iris
iris = load_iris()
features = iris.data.T
plt.scatter(features[0], features[1], alpha=0.2,
s=100*features[3], c=iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1]);

# %% [markdown]
# Esta configuración nos permite explorar 4 cuaracterísticas de los datos, las coordenadas x, y corresponden
# la longitud y ancho del sépalo, el tamaño al ancho del pétalo y el color a la especie correspondiente.
# Los gráficos de dispersión con multicolor y multiples características como este pueden ser muy útiles para
# explorar o presentar los datos

# %% [markdown]
# ## Visualización de errores
# ### Gráficos de error básicos

# %%
x = np.linspace(0, 10, 50)
dy = 0.8
y = np.sin(x) + dy * np.random.randn(50)
plt.errorbar(x, y, yerr=dy, fmt='.k');

# %% [markdown]
# Ahora, coloquemos los errores en un color más claro

# %%
plt.errorbar(x, y, yerr=dy, fmt='o', color='black',
ecolor='lightgray', elinewidth=3, capsize=0);

# %%
from sklearn.gaussian_process import GaussianProcessRegressor
# define the model and draw some data
model = lambda x: x * np.sin(x)
xdata = np.array([1, 3, 5, 6, 8])
ydata = model(xdata)
# Compute the Gaussian process fit
#kernel = C(1.0, (1e-3, 1e3)) * RBF(10, (1e-2, 1e2))
gp = GaussianProcessRegressor(kernel=None, n_restarts_optimizer=10) #OJO, esto se tuvo que editar, porque del libro, no corre porque cambió la función
gp.fit(xdata[:,np.newaxis],ydata)
xfit = np.linspace(0,10,1000)
yfit, sigma = gp.predict(xfit[:,np.newaxis], return_std=True)
dyfit = 2*sigma # 2*sigma ~ 95% confidence region

# %%
# Visualize the result
plt.plot(xdata, ydata, 'or')
plt.plot(xfit, yfit, '-', color='gray')
plt.fill_between(xfit, yfit - dyfit, yfit + dyfit,
color='gray', alpha=0.2)
plt.xlim(0, 10);

# %% [markdown]
# ### Anotaciones

# %%
fig, ax = plt.subplots()
x = np.linspace(0, 20, 1000)
ax.plot(x, np.cos(x))
ax.axis('equal')
ax.annotate('local maximum', xy=(6.28, 1), xytext=(10, 4),
arrowprops=dict(facecolor='black', shrink=0.05))
ax.annotate('local minimum', xy=(5 * np.pi, -1), xytext=(2, -6),
arrowprops=dict(arrowstyle="->",
connectionstyle="angle3,angleA=0,angleB=-90"));

# %%
filename = 'https://raw.githubusercontent.com/claudianila/MiRepoCS/main/Data/Casos_Diarios_Estado_Nacional_Confirmados_20211013.csv'
datos = pd.read_csv(filename,header=0)

# %%
data1=datos.loc[datos['nombre']=='Nacional']

# %%
data=data1.drop(['cve_ent','poblacion','nombre'],axis=1).T

# %%
data.reset_index(inplace=True)

# %%
data.dtypes
# Out:
# index    object
# 32        int64
# dtype: object

# %%
data.rename(columns={'index':'Fecha',32:'Nacional'},inplace=True)

# %%
data
# Out:
#           Fecha  Nacional
# 0    18-02-2020         0
# 1    19-02-2020         1
# 2    20-02-2020         0
# 3    21-02-2020         0
# 4    22-02-2020         0
# ..          ...       ...
# 599  09-10-2021      1812
# 600  10-10-2021      1395
# 601  11-10-2021      4614
# 602  12-10-2021      2201
# 603  13-10-2021        10
#
# [604 rows x 2 columns]

# %%
data.dtypes
# Out:
# Fecha       object
# Nacional     int64
# dtype: object

# %%
data['Fecha']=pd.to_datetime(data['Fecha'],format="%d-%m-%Y")

# %%
plt.plot(data.Fecha)

# %%
data.dtypes
# Out:
# Fecha       datetime64[ns]
# Nacional             int64
# dtype: object

# %%
#help(ax.annotate)

# %% [markdown]
# ## Ejemplo de anotaciones para Datos de COVID19

# %%
fig, ax = plt.subplots(figsize=(12, 6))
# Add labels to the plot
#plt.text(np.argmax(a), np.max(a) + 0.1, u'Máximo', fontsize = 10, horizontalalignment='center', verticalalignment='center')  # Colocamos texto cerca del valor donde se encuentra el máximo
#ax.annotate("Año Nuevo", (pd.to_datetime('2021/01/01'), 4100))
#plt.show()
#fig.savefig('STCovid19.png')
plt.plot("Fecha", "Nacional", data=data)
plt.xticks(rotation=15)
#plt.text(pd.to_datetime('2021/01/01'), 4100, u'Año Nuevo', fontsize = 10, horizontalalignment='center', verticalalignment='center')  # Colocamos texto cerca del valor donde se encuentra el valor
ax.annotate("Año Nuevo", xy=(pd.to_datetime('2021/01/01'), 4100), xycoords='data',
            xytext=(50, -30), textcoords='offset points',
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc3,rad=-0.2"))
ax.annotate("Día de la Independencia", xy=(pd.to_datetime('2020/09/16'), 4250), xycoords='data',
            bbox=dict(boxstyle="round", fc="none", ec="gray"),
            xytext=(10, -40), textcoords='offset points', ha='center',
            arrowprops=dict(arrowstyle="->"))
ax.annotate('Día de las Madres', xy=(pd.to_datetime('2021/05/10'), 4850), xycoords='data', ha='center',
            xytext=(0, -20), textcoords='offset points')
ax.annotate('Semana Santa 2020', xy=(pd.to_datetime('2020/04/05'), 4850), xytext=(pd.to_datetime('2020/04/19'), 4850),
            xycoords='data', textcoords='data',arrowprops={'arrowstyle': '|-|,widthA=0.2,widthB=0.2', })
ax.annotate('Semana Santa 2021', xy=(pd.to_datetime('2021/03/28'), 4850), xytext=(pd.to_datetime('2021/04/12'),4850),
                                     xycoords='data', textcoords='data',arrowprops={'arrowstyle': '|-|,widthA=0.2,widthB=0.2', })
ax.annotate('Halloween', xy=(pd.to_datetime('2020/10/31'), 5000), xycoords='data',
            xytext=(-30, 60), textcoords='offset points',arrowprops=dict(arrowstyle="fancy",
                                                                          fc="0.6", ec="none",connectionstyle="angle3,angleA=0,angleB=-90"))
ax.annotate('Navidad', xy=(pd.to_datetime('2020/12/25'), 4500), xycoords='data',
            xytext=(-120, -60), textcoords='offset points',
bbox=dict(boxstyle="round4,pad=.5", fc="0.9"),arrowprops=dict(arrowstyle="->",connectionstyle="angle,angleA=0,angleB=80,rad=20"))
ax.annotate('Inicio de Confinamiento Voluntario', xy=(pd.to_datetime('2020/03/20'), 3850), xycoords='data',
            xytext=(-30, 0), textcoords='offset points',size=13, ha='right', va="center",bbox=dict(boxstyle="round", alpha=0.1),
            arrowprops=dict(arrowstyle="wedge,tail_width=0.5", alpha=0.1));
ax.annotate('Incio de Vacunación Masiva', xy=(pd.to_datetime('2021/02/16'), 15000), xycoords='data',
            xytext=(30, 40), textcoords='offset points',arrowprops=dict(arrowstyle="fancy",
                                                                          fc="0.6", ec="none",connectionstyle="angle3,angleA=0,angleB=90"))
ax.annotate('Regreso a Clases Nivel Básico', xy=(pd.to_datetime('2021/08/30'), 15000), xycoords='data',
            xytext=(30, 40), textcoords='offset points',arrowprops=dict(arrowstyle="fancy",
                                                                          fc="0.6", ec="none",connectionstyle="angle3,angleA=0,angleB=90"))

plt.title('Casos Nacional COVID19 por día')
plt.ylabel=('Casos diarios')
plt.show()
plt.savefig('CasosCOVID19')

# %%
#Importamos datos de COVID
#Carga de datos
filename = 'C:/Users/jgeis/Documents/Claudia/Cursos/Impartidos/PythonParaCS/Bloque2  Limpieza de Datos y Análisis Descriptivo Univariado/dfCovidPositivos.csv'
df = pd.read_csv(filename, header=0)

# %%
df.columns
# Out:
# Index(['Muerto', 'EDAD', 'catEdad', 'SEXO', 'COMORBILIDADES', 'numComorb',
#        'HOSPITALIZADO', 'UCI', 'INTUBADO', 'dias_sintomas_ingreso',
#        'dias_ingreso_muerte', 'FECHA_INGRESO'],
#       dtype='object')

# %%
#Para que los análisis sean más rápidos, vamos a filtrar solo los menores de 18 años
df=df.loc[df['EDAD']==0]

# %%
df.Muerto.value_counts()
# Out:
# 0    5503
# 1     244
# Name: Muerto, dtype: int64

# %% [markdown]
# ### Gráficos de parejas

# %%
df2=df[['dias_sintomas_ingreso','dias_ingreso_muerte']]

# %%
#Gráfico de parejas, basado en: https://seaborn.pydata.org/generated/seaborn.pairplot.html
sns.pairplot(df2)

# %%
df2=df[['Muerto','dias_sintomas_ingreso','dias_ingreso_muerte']]

# %%
sns.pairplot(df2,hue="Muerto")
# Out:
# C:\Users\jgeis\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
### Gráficos de Calor

# %%
df_gptest = df[['Muerto','HOSPITALIZADO','dias_sintomas_ingreso']]
grouped_test1 = df_gptest.groupby(['Muerto','HOSPITALIZADO'],as_index=False).mean()
grouped_test1
# Out:
#    Muerto  HOSPITALIZADO  dias_sintomas_ingreso
# 0       0              0               2.588155
# 1       0              1               1.738445
# 2       1              0               3.666667
# 3       1              1               2.698690

# %%
grouped_pivot = grouped_test1.pivot(index='Muerto',columns='HOSPITALIZADO')
grouped_pivot
# Out:
#               dias_sintomas_ingreso
# HOSPITALIZADO                     0         1
# Muerto
# 0                          2.588155  1.738445
# 1                          3.666667  2.698690

# %%
grouped_pivot = grouped_pivot.fillna(0) 
grouped_pivot
# Out:
#               dias_sintomas_ingreso
# HOSPITALIZADO                     0         1
# Muerto
# 0                          2.588155  1.738445
# 1                          3.666667  2.698690

# %%
plt.pcolor(grouped_pivot)
plt.colorbar()
plt.show()

# %%
# Cambiamos las etiquetas
fig, ax = plt.subplots()
im = ax.pcolor(grouped_pivot, cmap='RdBu')

#label names
row_labels = grouped_pivot.columns.levels[1]
col_labels = grouped_pivot.index

#move ticks and labels to the center
ax.set_xticks(np.arange(grouped_pivot.shape[1]) + 0.5, minor=False)
ax.set_yticks(np.arange(grouped_pivot.shape[1]) + 0.5, minor=False)

#insert labels
ax.set_xticklabels(row_labels, minor=False)
ax.set_yticklabels(col_labels, minor=False)

#rotate label if too long
plt.xticks(rotation=90)

fig.colorbar(im)
plt.show()
